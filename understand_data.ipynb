# %%
import numpy as numpy
import torch
import pandas
import matplotlib.pyplot as plt

# %%
base = "/vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/"
ecgs =      "ecgs_train_BMI_noBase_gn.pt"
labels =  "labels_train_BMI.pt"
#path = "./mimic_data_0-10000.pt"

# %%
data = torch.load(base + ecgs)
data.shape
# Out:
# torch.Size([5130, 12, 5000])

# %%
targets = torch.load(base + labels)
len(targets)
# Out:
# 5130

# %%
patient1 = data[1]
patient1.shape
# Out:
# torch.Size([12, 5000])

# %%
fig, axs = plt.subplots(len(patient1))
plt.figure(figsize=(20,12))

for i,channel in enumerate(patient1):
    axs[i].plot(channel)

plt.show()

# %%
import os
rootdir = "/vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/"
extensions = ('.pt')
counter = 0

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        ext = os.path.splitext(file)[-1].lower()
        if ext in extensions and "ecgs_" in file:
            data = torch.load(os.path.join(subdir, file))
            print(os.path.join(subdir, file), data.shape)
    counter += 1
    if counter>5: break
# Out:
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_train_flutter_hundredth_balanced_noBase_gn.pt torch.Size([16, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_train_flutter_all_balanced_noBase_gn.pt torch.Size([1698, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_test_BMI_noBase_gn.pt torch.Size([1125, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_test_ecg_imaging_noBase_gn.pt torch.Size([6007, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_val_BMI_noBase_gn.pt torch.Size([1050, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_val_Regression_noBase_gn.pt torch.Size([2835, 12, 5000])
# /vol/aimspace/projects/ukbb/data/cardiac/cardiac_segmentations/projects/ecg/ecgs_val_BMI_balanced_noBase_gn.pt torch.Size([86, 12, 5000])
# ...
